# %% [markdown]
# # Exercise 1: %timeit list vs NumPy
# Lesson 00/05. 100_000 random numbers.

# %%
import numpy as np

# %%
# %timeit [x for x in range(100_000)]
# Out:
# 1.36 ms ± 10.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit [np.random.random() for _ in range(100_000)]
# Out:
# 12.7 ms ± 118 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.random.rand(100_000)
# Out:
# 285 μs ± 4.15 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
